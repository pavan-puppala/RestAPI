# %% [markdown]
# ## API: Application Programming Interface
# - communication between two different application is called API
# - Ex: we are accessing the data from servers to our mobile
# - weather details we are accessing from weather forecasting
# - IRCTC while payment from IRCTC we are accessing our bank details

# %% [markdown]
# #### Note:for this we are using the pycharm(to do projects becoz we are using .py,.html files) because jupyter notebook only just for learning Exploratory Data Analysis

# %% [markdown]
# #### Web application  -- Development -- Framework(many inbuilt functionalities)
#                                          |--> libraries
#                                                    |-->methods or Functions(books in library)
# #### - flask is a framework supported by python

# %%
from IPython.display import Image
Image("E:/code/RestAPI/img/rest1.png")

# %% [markdown]
# - create a folder(flask_demo)
# - open pycharm with respective to the folder path (file --> open --> flask_demo folder)
# - create new conda Environment(by default we have base Environment)
#     - An environment just like an isolated space(to store project related libraries).
#     - for Example: i have "A" library which is dependent on "B" library of Version 3.5
#     - now i want to install "C" library which is dependent on "B" library of verssion 3.2
#     - here a conflict raises between two different versions. To overcome this we create two different environment
# - file --> settings --> select your project(project: flask_demo) --> project Interpreter --> gear icon(settings) --> add --> conda env --> new Environment --> ok

# %% [markdown]
# ### Step2:
# - Route
# - intall Flask: pip install flask
# - create new python file in project folder(flask_demo)

# %% [markdown]
# #### application.py

# %%
from IPython.display import Image
Image("E:/code/RestAPI/img/rest2.png")

# %% [markdown]
# - run the application.py file

# %%
from IPython.display import Image
Image("E:/code/RestAPI/img/rest3.png")

# %% [markdown]
# - request comming to our API is JSON Request

# %% [markdown]
# ## Step3: to test API we use POSTMAN tool
# - download and install the postman tool https://www.postman.com/downloads/
# - method: POST, url: http://127.0.0.1:5000/math , headers: content type, Application/Json, Body: provide json data

# %%
from IPython.display import Image
Image("E:/code/RestAPI/img/rest4.png")

# %% [markdown]
# ## Step4: write remaining operations

# %%
from IPython.display import Image
Image("E:/code/RestAPI/img/rest5.png")

# %% [markdown]
# ## Step5: Creating UI(HTML pages)
# - Flask has a fixed structure so we have to maintain fixed directory(templates/html, static/css)
# - create two new directories(templates and Static)
# - inside to templates --> create input.html

# %%
from IPython.display import Image
Image("E:/code/RestAPI/img/rest6.png")

# %%
from IPython.display import Image
Image("E:/code/RestAPI/img/rest7.png")

# %% [markdown]
# ## Exercise:calculator

# %%
from IPython.display import Image
Image("E:/code/RestAPI/img/rest8.png")

# %% [markdown]
# #### input.html

# %%
{% block head %}

<title>Calculator</title>
<link rel="stylesheet" href="{{ url_for('static', filename='css/style.css') }}">
{% endblock %}

{% block body %}
<div class="content">
    <h1 style="text-align: center">Calculator</h1>

    <div class="form">
        <form action="/math" method="POST">
            <label for="operation">Choose a Mathematical Operation</label>

<select id="operation" name="operation">
  <option value="add">add</option>
  <option value="sub">subtract</option>
  <option value="mul">multiply</option>
  <option value="div">divide</option>
</select><br>
            <label for="num1">First Number:</label>
            <input type="text" name="num1" id="num1"><br>
            <label for="num2">Second Number:</label>
            <input type="text" name="num2" id="num2"><br>
            <input type="submit" value="Calculate">
        </form>
    </div>
</div>
{% endblock %}
# Out:
#   File "<ipython-input-2-f80dea3de694>", line 2
#     {% block head %}
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### calculator.py

# %%
from flask import Flask, render_template, request, jsonify

app = Flask(__name__)


@app.route('/', methods=['GET', 'POST']) # To render Homepage
def home_page():
    return render_template('input.html')

@app.route('/math', methods=['POST'])  # This will be called from UI
def math_operation():
    if (request.method=='POST'):
        operation=request.form['operation']
        num1=int(request.form['num1'])
        num2 = int(request.form['num2'])
        if(operation=='add'):
            r=num1+num2
            result= 'the sum of '+str(num1)+' and '+str(num2) +' is '+str(r)
        elif (operation == 'sub'):
            r = num1 - num2
            result = 'the difference of ' + str(num1) + ' and ' + str(num2) + ' is ' + str(r)
        elif (operation == 'mul'):
            r = num1 * num2
            result = 'the product of ' + str(num1) + ' and ' + str(num2) + ' is ' + str(r)
        elif (operation == 'div'):
            r = num1 / num2
            result = 'the quotient when ' + str(num1) + ' is divided by ' + str(num2) + ' is ' + str(r)
        return render_template('output.html',result=result)

@app.route('/via_postman', methods=['POST']) # for calling the API from Postman/SOAPUI
def math_operation_via_postman():
    if (request.method=='POST'):
        operation=request.json['operation']
        num1=int(request.json['num1'])
        num2 = int(request.json['num2'])
        if(operation=='add'):
            r=num1+num2
            result= 'the sum of '+str(num1)+' and '+str(num2) +' is '+str(r)
        elif (operation == 'sub'):
            r = num1 - num2
            result = 'the difference of ' + str(num1) + ' and ' + str(num2) + ' is ' + str(r)
        elif (operation == 'mul'):
            r = num1 * num2
            result = 'the product of ' + str(num1) + ' and ' + str(num2) + ' is ' + str(r)
        elif (operation == 'div'):
            r = num1 / num2
            result = 'the quotient when ' + str(num1) + ' is divided by ' + str(num2) + ' is ' + str(r)
        return jsonify(result)


if __name__ == '__main__':
    app.run(debug=True)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Restarting with windowsapi reloader
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\Users\LENOVO\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2971: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# #### output.html

# %%
<!DOCTYPE html>
<html lang="en" >

<head>
  <meta charset="UTF-8">
  <title>Review Page</title>
    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/normalize/5.0.0/normalize.min.css">
      <link rel="stylesheet" href="./style.css">
    <link rel="stylesheet" href="{{ url_for('static', filename='css/style.css') }}">
</head>
<body>
  <div class="table-users">
   <div class="header">Calculation Result</div>

      {{result}}
</div>
</body>
</html>
# Out:
#   File "<ipython-input-4-380da32db2bb>", line 1
#     <!DOCTYPE html>
#     ^
# SyntaxError: invalid syntax
